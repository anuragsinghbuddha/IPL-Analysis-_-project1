# %%
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
ipl=pd.read_csv("Match.csv")
ipl
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# ...

# %%
ipl['Win_Type'].replace({'runs':1,'wickets':0,'run':1,'Tie':0,'No Result':0,'NA':0},inplace=True)

# %%
ipl.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %%
ipl.shape # counting no. of rows as columns
# Out:
# (637, 17)

# %%
ipl['ManOfMach'].value_counts()#getting the no man of the match recived by players
# Out:
# CH Gayle           18
# YK Pathan          16
# DA Warner          15
# AB de Villiers     15
# RG Sharma          14
#                    ..
# JJ Bumrah           1
# KMDN Kulasekara     1
# DJ Hooda            1
# Q de Kock           1
# AD Mathews          1
# Name: ManOfMach, Length: 202, dtype: int64

# %%
ipl['ManOfMach'].value_counts()[0:10]# top 10 max man of the match recive by player
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# G Gambhir         13
# MS Dhoni          13
# MEK Hussey        12
# AM Rahane         12
# Name: ManOfMach, dtype: int64

# %%
bating_first=ipl[ipl['Win_Type']!=0]
bating_first.head()
# Out:
#     Match_SK  match_id                        Team1                  Team2  \
# 0          0    335987  Royal Challengers Bangalore  Kolkata Knight Riders
# 1          1    335988              Kings XI Punjab    Chennai Super Kings
# 7          7    335994          Chennai Super Kings         Mumbai Indians
# 9          9    335996              Kings XI Punjab         Mumbai Indians
# 14        14    336001  Royal Challengers Bangalore    Chennai Super Kings
#
#    match_date  Season_Year                                  Venue_Name  \
# 0   4/18/2008         2008                       M Chinnaswamy Stadium
# 1   4/19/2008         2008  Punjab Cricket Association Stadium, Mohali
# 7   4/23/2008         2008             MA Chidambaram Stadium, Chepauk
# 9   4/25/2008         2008  Punjab Cricket Association Stadium, Mohali
# 14  4/28/2008         2008                       M Chinnaswamy Stadium
#
#      City_Name Country_Name                  Toss_Winner  \
# ...

# %%
bating_first['match_winner'].value_counts() # no. of match win after batting first by each time
# Out:
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Sunrisers Hyderabad            23
# Rajasthan Royals               23
# Delhi Daredevils               21
# Deccan Chargers                18
# Rising Pune Supergiants         7
# Pune Warriors                   6
# Kochi Tuskers Kerala            2
# abandoned                       1
# Gujarat Lions                   1
# tied                            1
# Name: match_winner, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(list(bating_first['match_winner'].value_counts()),labels=list(bating_first['match_winner'].value_counts().keys()),autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x15b1fbd4400>,
# ...
#  [Text(0.9595264325352306, 0.5378745441701194, 'Mumbai Indians'),
#   Text(0.053787843187821746, 1.0986841529416915, 'Chennai Super Kings'),
#   Text(-0.7883144781637839, 0.7671768267598815, 'Kings XI Punjab'),
#   Text(-1.0958430686688145, 0.09554040428277456, 'Kolkata Knight Riders'),
#   Text(-0.9224290639735474, -0.5992700742877833, 'Royal Challengers Bangalore'),
#   Text(-0.44704614193293574, -1.0050620612593422, 'Sunrisers Hyderabad'),
#   Text(0.08958284802746383, -1.0963461649220507, 'Rajasthan Royals'),
#   Text(0.5841501083970517, -0.9320775991620617, 'Delhi Daredevils'),
#   Text(0.9158602985429624, -0.6092617775248961, 'Deccan Chargers'),
#   Text(1.0457920424819613, -0.3410557196139772, 'Rising Pune Supergiants'),
#   Text(1.0834036896573114, -0.19035872776661536, 'Pune Warriors'),
#   Text(1.0958430685290468, -0.09554040588590301, 'Kochi Tuskers Kerala'),
#   Text(1.0983755752101065, -0.05975864608462569, 'abandoned'),
# ...
